# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
data = pd.read_csv("simple_linear_regression_with_dummy.csv")
data

data2 = pd.read_csv("rand_dummy.csv")
data2
# Out:
#      SAT   GPA  Rand 1,2,3
# 0   1714  2.40           1
# 1   1664  2.52           3
# 2   1760  2.54           3
# 3   1685  2.74           3
# 4   1693  2.83           2
# ..   ...   ...         ...
# 79  1936  3.71           3
# 80  1810  3.71           1
# 81  1987  3.73           3
# 82  1962  3.76           1
# 83  2050  3.81           2
#
# [84 rows x 3 columns]

# %%
data2.describe()
# Out:
#                SAT        GPA  Rand 1,2,3
# count    84.000000  84.000000   84.000000
# mean   1845.273810   3.330238    2.059524
# std     104.530661   0.271617    0.855192
# min    1634.000000   2.400000    1.000000
# 25%    1772.000000   3.190000    1.000000
# 50%    1846.000000   3.380000    2.000000
# 75%    1934.000000   3.502500    3.000000
# max    2050.000000   3.810000    3.000000

# %%
y = data['GPA']
x1 = data[['SAT','Dummy']]


y2 = data2['GPA']
x2 = data2[['SAT','Rand 1,2,3']]

# %%
data.isnull().sum()
# Out:
# SAT      0
# GPA      0
# Dummy    1
# dtype: int64

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.419
# Model:                            OLS   Adj. R-squared:                  0.404
# Method:                 Least Squares   F-statistic:                     29.15
# Date:                Thu, 19 Sep 2024   Prob (F-statistic):           2.90e-10
# Time:                        14:07:19   Log-Likelihood:                 13.568
# No. Observations:                  84   AIC:                            -21.14
# Df Residuals:                      81   BIC:                            -13.84
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1949      0.411      0.474      0.637      -0.624       1.013
# ...

# %%
x3 = sm.add_constant(x2)
results2 = sm.OLS(y2,x3).fit()

# %%
results2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    GPA   R-squared:                       0.407
# Model:                            OLS   Adj. R-squared:                  0.392
# Method:                 Least Squares   F-statistic:                     27.76
# Date:                Thu, 19 Sep 2024   Prob (F-statistic):           6.58e-10
# Time:                        14:16:44   Log-Likelihood:                 12.720
# No. Observations:                  84   AIC:                            -19.44
# Df Residuals:                      81   BIC:                            -12.15
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2960      0.417      0.710      0.480      -0.533       1.125
# ...

# %% [markdown]
# ##
